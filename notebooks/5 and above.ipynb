# %%
import pandas as pd

# %%
path = "../data/pirate life/address.csv"

# %%
df = pd.read_csv(path)

# %%
# Batch One
df = df[df["Batch"] == "1"]

# %%
df
# Out:
#                  name  number  \
# 125  Pirate Life #126     126
# 126  Pirate Life #127     127
# 127  Pirate Life #128     128
# 128  Pirate Life #129     129
# 129  Pirate Life #130     130
# ..                ...     ...
# 395  Pirate Life #396     396
# 396  Pirate Life #397     397
# 397  Pirate Life #398     398
# 398  Pirate Life #399     399
# 399  Pirate Life #400     400
#
#                                                  image           date Batch  \
# 125  https://nft.hedgey.finance/fantom/0xb75b8dac01...  1661524254706     1
# 126  https://nft.hedgey.finance/fantom/0xb75b8dac01...  1661524282030     1
# 127  https://nft.hedgey.finance/fantom/0xb75b8dac01...  1661524282164     1
# 128  https://nft.hedgey.finance/fantom/0xb75b8dac01...  1661524335023     1
# 129  https://nft.hedgey.finance/fantom/0xb75b8dac01...  1661524335163     1
# ..                                                 ...            ...   ...
# ...

# %%
df["address"].value_counts().loc[lambda x : x>4].reset_index().to_csv("5 and above.csv")
